# %% [markdown]
# ## <font color='#2F4F4F'>1. Defining the Question</font>

# %% [markdown]
# ### a) Specifying the Data Analysis Question
#
# What is your research question? What problem is it that you are trying to solve?
#
# I am trying to resolve churn in MTN, by analysing and understanding the behaviour of the company's customers.The solution will see a reduction in churn.

# %% [markdown]
# ### b) Defining the Metric for Success
#
# What will convince you that your project has succeeded?
#
# Reduction in churn.

# %% [markdown]
# ### c) Understanding the Context
#
# The background information surrounding the problem or research question.
#
# Churn management is important in any organization, customers leave due to many reasons.
# By predicting churn and resolving churn before it happens will improve the company's image as well as it's financials.
# Hence this project will help management reduce churn, by understanding the customers.

# %% [markdown]
# ### d) Recording the Experimental Design
#
# The steps you will take from the beginning to the end of this project.
#
# The steps to be taken include:
#
# <li> Defining the Research Question
# <li> Data Importation
# <li> Data Exploration
# <li> Data Cleaning
# <li> Data Analysis (Univariate and Bivariate)
# <li> Data Preparation
# <li> Data Modeling
# <li> Model Evaluation
# <li> Challenging your Solution
# <li> Recommendations / Conclusion

# %% [markdown]
# ### e) Data Relevance
#
# Is the provided data relevant to the problem or research question?
#
# The data contains relevant data on whether the customer churned or not, Hence relevant to our study.

# %% [markdown]
# ## <font color='#2F4F4F'>2. Data Cleaning & Preparation</font>

# %%
# load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# to display all columns
pd.set_option('display.max.columns', None)

# to display the entire contents of a cell
pd.set_option('display.max_colwidth', None)

# %%
# load and preview dataset
df = pd.read_csv('call-center-data-QueryResult.csv')
df.sample(3)
# Out:
#       recordid  customer_id  account_length  area_code  international_plan  \
# 7477      7478   51190106.0              96        415               False
# 4876      4877   57291361.0              68        415                True
# 4376      4377   23036973.0             193        415               False
#
#       total_intl_minutes  total_intl_calls  voice_mail_plan  \
# 7477                 9.1                 7            False
# 4876                14.2                 6             True
# 4376                11.7                 3             True
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 7477                      0              173.9              111
# 4876                     24              125.7               92
# 4376                     31               71.2               58
#
#       total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 7477             29.56              287.4              105             24.43
# 4876             21.37              275.9               98             23.45
# 4376             12.10              124.7              105             10.60
#
#       total_night_minutes  total_night_calls  total_night_charge  \
# 7477                204.8                 91                9.22
# 4876                214.5                108                9.65
# 4376                155.5                108                7.00
#
#       total_intl_minutes_2  total_intl_calls_2  total_intl_charge  \
# 7477                   9.1                   7               2.46
# 4876                  14.2                   6               3.83
# 4376                  11.7                   3               3.16
#
#       number_customer_service_calls  churn
# 7477                              1  False
# 4876                              3   True
# 4376                              0  False

# %%
# load glossary
glossary = pd.read_csv('classification_analysis_glossary.csv',header = None)
glossary
# Out:
#                                                                                          0
# 0                                               account_length - Age of account in months.
# 1                                             customer_id - Enterprise ID of the customer.
# 2                                                                   area_code - Area code.
# 3       international_plan - Rather or not the customer has an international calling plan.
# 4                      voice_mail_plan - Rather or not the customer has a voice mail plan.
# 5      number_vmail_messages - Number of VM messages customer currently has on the server.
# 6                        total_day_minutes - Customers total usage of day minutes in plan.
# 7                total_day_calls - Total number of calls customer has made during the day.
# 8               total_day_charge - How much the customer has been charged for day minutes.
# 9          total_eve_minutes - Total number of calls customer has made during the evening.
# 10          total_eve_charge - How much the customer has been charged for evening minutes.
# 11                   total_night_minutes - Customers total usage of night minutes in plan.
# 12           total_night_calls - Total number of calls customer has made during the night.
# 13          total_night_charge - How much the customer has been charged for night minutes.
# 14                                       total_intl_minutes - Total international minutes.
# 15                                           total_intl_calls - Total international calls.
# 16                                        total_intl_charge - Total international charges.
# 17  number_customer_service_calls - How many times the customer has called the IVR system.
# 18                                                           churn - Customer has churned.

# %%
# check dataset shape
df.shape
# Out:
# (12892, 23)

# %% [markdown]
# Our dataset has 12,892 records and 23 variables.

# %% [markdown]
# We will drop 'recordid' and 'customer_id' since we have no need of them and they would interfere with our analysis.

# %%
df.drop(columns = ['recordid', 'customer_id'], inplace = True)

# %%
# preview variable datatypes
df.dtypes
# Out:
# account_length                     int64
# area_code                          int64
# international_plan                  bool
# total_intl_minutes               float64
# total_intl_calls                   int64
# voice_mail_plan                     bool
# number_vmail_messages              int64
# total_day_minutes                float64
# total_day_calls                    int64
# total_day_charge                 float64
# total_eve_minutes                float64
# total_eve_calls                    int64
# total_eve_charge                 float64
# total_night_minutes              float64
# total_night_calls                  int64
# total_night_charge               float64
# total_intl_minutes_2             float64
# total_intl_calls_2                 int64
# total_intl_charge                float64
# number_customer_service_calls      int64
# churn                               bool
# dtype: object

# %% [markdown]
# With the exception of the 'international_plan', 'voice_mail_plan', and 'churn' variables which are boolean, this dataset is numerical.

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 7892

# %% [markdown]
# 7,892 duplicated records are found. We will drop them.

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (5000, 21)

# %%
# check for missing values
df.isna().sum()
# Out:
# account_length                   0
# area_code                        0
# international_plan               0
# total_intl_minutes               0
# total_intl_calls                 0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes_2             0
# total_intl_calls_2               0
# total_intl_charge                0
# number_customer_service_calls    0
# churn                            0
# dtype: int64

# %% [markdown]
# No missing values found. We will look at the unique values in each variable just to be safe.

# %%
columns = df.columns

for col in columns:
    print("Variable:", col)
    print("Number of unique values:", df[col].nunique())
    print(df[col].unique())
    print()
# Out:
# Variable: account_length
# Number of unique values: 218
# [101 137 103  99 108 117  63  94 138 128 113 140 102  60  96 178  75 106
#  158 111  92  42  69  76  72 115  68  97  90  73  54 161 125 194 141  98
#  110  70  66  79  61  77 105 159  83  93 163 169  57  85 132 190  39  84
#   71 114 135  82  64 112 166 120 187 100  45  43  52  74  40  56 133 119
#  131 118 107 109 127  33 145  47  53 148  55 143 170  65 157  89  91 104
#  130  80 146  29  78 185 144  59 139  12 150 156  17 176  95 136 165 149
#  124  87  51 126  62  48  58  81  36 177  25 171 122  44 167  41 184  88
#  151 160 152  49  13 142   3  23  19 154 116 173  24  15  86 147  21 174
#  162 186  14   7   1  18  20  11 192 121 134  67 164 180  35 155  32 123
#  182 129  38  37  50  27 188 175   5  26   4  31 193 238  28 195 153 201
#  216 183 168 222 232 233  22  46  34   8 217   2 200 172  16  30 202 181
#   10   6 179 208 215 199 196 209 224 189 243 205   9 210 212 197 225 191
#  204 221]
#
# Variable: area_code
# Number of unique values: 3
# [510 408 415]
#
# Variable: international_plan
# Number of unique values: 2
# [False  True]
#
# Variable: total_intl_minutes
# Number of unique values: 170
# [10.6  9.5 13.7 15.7  7.7  6.9 12.9 11.1  9.9 11.9  9.  10.5  7.2  7.4
#  14.3 11.7 13.9  7.1 14.7  9.8  9.3 11.   5.2  9.2 10.1 12.3  9.1 12.6
#  10.  12.  10.7 13.4  8.3 13.6 12.5 10.2  4.4  8.6  6.8 11.8 16.2 13.2
#   8.  11.4 12.4 10.4  7.5 12.8 18.9  7.6  0.  11.3 13.8  7.   9.6  8.8
#   7.3 15.1  7.9 11.6  6.1  8.7 13.3 10.3  5.7 10.9  7.8  5.6 13.5  9.7
#  14.8  8.9  9.4  8.5 12.7 15.4  5.4 14.   8.2  6.6 11.5 12.1 13.1 11.2
#   8.4 14.9  6.   6.3  4.5  8.1  6.2  3.9  4.6 12.2 13.   6.7 15.6 14.2
#  18.7 10.8  5.8 15.   5.9  4.3  5.5 16.8 14.5  4.8  5.3  4.7 16.1 14.1
#  15.2 15.3 16.5 16.3  3.1  5.1  6.5  3.7  3.8 17.2  4.2  0.4 19.3 14.6
#  19.2  6.4 16.6  2.2 15.9  5.  14.4 15.5  4.9 19.7 16.  15.8 17.8  3.4
#  18.5  3.5  4.1 16.4  4.   1.1  2.  17.7 20.  17.6  2.7 18.  17.5 18.2
#   3.6 16.7  1.3 16.9 17.  17.1 17.9 17.3 18.4  2.9  3.3  2.6 18.3  2.1
#   2.4  2.5]
#
# Variable: total_intl_calls
# Number of unique values: 21
# [ 3  7  6  2  4  5  1  9  8 13  0 12 10 19 16 11 15 18 17 14 20]
#
# Variable: voice_mail_plan
# Number of unique values: 2
# [False  True]
#
# Variable: number_vmail_messages
# Number of unique values: 48
# [ 0 29 32 43 39 22 25 35 31 38 41  6 37 30 40 33 36 12 21 46 27 20 18 24
#  28 34 15 26 45 49 19 17 16 14 23 42 10 47 48 52 44 51 11  8  4 13 50  9]
#
# Variable: total_day_minutes
# Number of unique values: 1961
# [ 70.9 223.6 294.7 ... 224.1 124.9 321.1]
#
# Variable: total_day_calls
# Number of unique values: 123
# [123  86  95  78  85 124  97 117 100  77 109  93  66 105 121 142  88  99
#  101 111  94 110 125 106  74 131 112 104  76 113 122 127  65  91  48 120
#  102 103  81 108  83  56 118  75  57 132 114  92 126  98 119  87  82  96
#  107  90  64 133  89 115 147  58  72  80  53 128 130 149  79  68 143 141
#   61 116 148  84  62  60  51  73 135 137 151 136 134  50  71  70 129  52
#  138  69  59  67 144  63  47  34  39 156 157 146  44  46 140 152 139 160
#   49 145  55 158 163  54  36  40 150 165  30  42   0  45  35]
#
# Variable: total_day_charge
# Number of unique values: 1961
# [12.05 38.01 50.1  ... 38.1  21.23 54.59]
#
# Variable: total_eve_minutes
# Number of unique values: 1879
# [211.9 244.8 237.3 ... 153.4 288.8 265.9]
#
# Variable: total_eve_calls
# Number of unique values: 126
# [ 73 139 105  88 101  68 125 112  46  89  90 116  97 107 100  81 108 104
#  106 120  71  70 131 128  91 109 126  75  87  78  94 127  62 103 110  96
#  136  67 148 117  95  98  92 111  99  63 119 123  93 102  86 121  56 118
#  114 133  76  79  65  85  72 113 115 132  84 143 130  83 124 142 150  74
#  129 138  61 122  80  77 134  82 151 147  58  69 141  66  55  64  47 144
#  169 149  53 140 152  54 154  60 135 145 155  51  52 137  38  57  44 146
#   49 164  59  48 168  42  37  12  50 157  45  36 156 153  43   0 159 170]
#
# Variable: total_eve_charge
# Number of unique values: 1659
# [18.01 20.81 20.17 ... 13.04 24.55 22.6 ]
#
# Variable: total_night_minutes
# Number of unique values: 1853
# [236.   94.2 300.3 ... 131.9 280.9 279.1]
#
# Variable: total_night_calls
# Number of unique values: 131
# [ 73  81 127  82 107  90 120 106  71  92 100  94 124 119  89 114  99  98
#   95 104 121  80 125  78 105  96 103 115  79 101 132  72  85 110  83  84
#  109 118 134 116  64 113  88 123 135  56  68 148  76  93  91  97 141 102
#  139 136 131  58 129 112  49  48 128 122  77 151 145 108 130 117  69  53
#   66  40  87  70  75 111 168 149 137 161 133  67 138  65  60  74 126  61
#  150 143 140 146 159 142 160  57  86 170 158  63  62  52 147 154  42  41
#   59  50  38  46 155  12  55 165  54  43  51   0 152  44 153 175 157 144
#  166  33 156  36 164]
#
# Variable: total_night_charge
# Number of unique values: 1028
# [10.62  4.24 13.51 ...  5.12  5.65 12.37]
#
# Variable: total_intl_minutes_2
# Number of unique values: 170
# [10.6  9.5 13.7 15.7  7.7  6.9 12.9 11.1  9.9 11.9  9.  10.5  7.2  7.4
#  14.3 11.7 13.9  7.1 14.7  9.8  9.3 11.   5.2  9.2 10.1 12.3  9.1 12.6
#  10.  12.  10.7 13.4  8.3 13.6 12.5 10.2  4.4  8.6  6.8 11.8 16.2 13.2
#   8.  11.4 12.4 10.4  7.5 12.8 18.9  7.6  0.  11.3 13.8  7.   9.6  8.8
#   7.3 15.1  7.9 11.6  6.1  8.7 13.3 10.3  5.7 10.9  7.8  5.6 13.5  9.7
#  14.8  8.9  9.4  8.5 12.7 15.4  5.4 14.   8.2  6.6 11.5 12.1 13.1 11.2
#   8.4 14.9  6.   6.3  4.5  8.1  6.2  3.9  4.6 12.2 13.   6.7 15.6 14.2
#  18.7 10.8  5.8 15.   5.9  4.3  5.5 16.8 14.5  4.8  5.3  4.7 16.1 14.1
#  15.2 15.3 16.5 16.3  3.1  5.1  6.5  3.7  3.8 17.2  4.2  0.4 19.3 14.6
#  19.2  6.4 16.6  2.2 15.9  5.  14.4 15.5  4.9 19.7 16.  15.8 17.8  3.4
#  18.5  3.5  4.1 16.4  4.   1.1  2.  17.7 20.  17.6  2.7 18.  17.5 18.2
#   3.6 16.7  1.3 16.9 17.  17.1 17.9 17.3 18.4  2.9  3.3  2.6 18.3  2.1
#   2.4  2.5]
#
# Variable: total_intl_calls_2
# Number of unique values: 21
# [ 3  7  6  2  4  5  1  9  8 13  0 12 10 19 16 11 15 18 17 14 20]
#
# Variable: total_intl_charge
# Number of unique values: 170
# [2.86 2.57 3.7  4.24 2.08 1.86 3.48 3.   2.67 3.21 2.43 2.84 1.94 2.
#  3.86 3.16 3.75 1.92 3.97 2.65 2.51 2.97 1.4  2.48 2.73 3.32 2.46 3.4
#  2.7  3.24 2.89 3.62 2.24 3.67 3.38 2.75 1.19 2.32 1.84 3.19 4.37 3.56
#  2.16 3.08 3.35 2.81 2.03 3.46 5.1  2.05 0.   3.05 3.73 1.89 2.59 2.38
#  1.97 4.08 2.13 3.13 1.65 2.35 3.59 2.78 1.54 2.94 2.11 1.51 3.65 2.62
#  4.   2.4  2.54 2.3  3.43 4.16 1.46 3.78 2.21 1.78 3.11 3.27 3.54 3.02
#  2.27 4.02 1.62 1.7  1.22 2.19 1.67 1.05 1.24 3.29 3.51 1.81 4.21 3.83
#  5.05 2.92 1.57 4.05 1.59 1.16 1.49 4.54 3.92 1.3  1.43 1.27 4.35 3.81
#  4.1  4.13 4.46 4.4  0.84 1.38 1.76 1.   1.03 4.64 1.13 0.11 5.21 3.94
#  5.18 1.73 4.48 0.59 4.29 1.35 3.89 4.19 1.32 5.32 4.32 4.27 4.81 0.92
#  5.   0.95 1.11 4.43 1.08 0.3  0.54 4.78 5.4  4.75 0.73 4.86 4.73 4.91
#  0.97 4.51 0.35 4.56 4.59 4.62 4.83 4.67 4.97 0.78 0.89 0.7  4.94 0.57
#  0.65 0.68]
#
# Variable: number_customer_service_calls
# Number of unique values: 10
# [3 0 1 2 4 5 6 7 9 8]
#
# Variable: churn
# Number of unique values: 2
# [False  True]

# %% [markdown]
# We can confirm that there are no missing values in this dataset.

# %% [markdown]
# An anomaly has been noted: there appears to be duplicated columns between 'total_intl_minutes' and 'total_intl_minutes_2', and 'total_intl_calls' and 'total_intl_calls_2'. Let's preview them:

# %%
# previewing the possibly duplicated columns
df[['total_intl_minutes', 'total_intl_calls', 'total_intl_minutes_2', 'total_intl_calls_2']]
# Out:
#       total_intl_minutes  total_intl_calls  total_intl_minutes_2  \
# 0                   10.6                 3                  10.6
# 1                    9.5                 7                   9.5
# 2                   13.7                 6                  13.7
# 3                   15.7                 2                  15.7
# 4                    7.7                 4                   7.7
# ...                  ...               ...                   ...
# 4995                 9.9                 6                   9.9
# 4996                 9.6                 4                   9.6
# 4997                14.1                 6                  14.1
# 4998                 5.0                10                   5.0
# 4999                13.7                 4                  13.7
#
#       total_intl_calls_2
# 0                      3
# 1                      7
# 2                      6
# 3                      2
# 4                      4
# ...                  ...
# 4995                   6
# 4996                   4
# 4997                   6
# 4998                  10
# 4999                   4
#
# [5000 rows x 4 columns]

# %% [markdown]
# The last two columns appear to be complete copies of the first two. We will confirm this so that we do not blindly drop them.

# %%
# selecting the total number of records where the values of 'total_intl_minutes' are equal to the values of 
# 'total_intl_minutes_2', AND the values of 'total_intl_calls' are equal to the values of 'total_intl_calls_2'
df[(df['total_intl_minutes'] == df['total_intl_minutes_2']) & (df['total_intl_calls'] == df['total_intl_calls_2'])].count()
# Out:
# account_length                   5000
# area_code                        5000
# international_plan               5000
# total_intl_minutes               5000
# total_intl_calls                 5000
# voice_mail_plan                  5000
# number_vmail_messages            5000
# total_day_minutes                5000
# total_day_calls                  5000
# total_day_charge                 5000
# total_eve_minutes                5000
# total_eve_calls                  5000
# total_eve_charge                 5000
# total_night_minutes              5000
# total_night_calls                5000
# total_night_charge               5000
# total_intl_minutes_2             5000
# total_intl_calls_2               5000
# total_intl_charge                5000
# number_customer_service_calls    5000
# churn                            5000
# dtype: int64

# %% [markdown]
# We see that the columns are indeed duplicates so we can safely drop them.

# %%
df = df.drop(columns = ['total_intl_minutes_2', 'total_intl_calls_2'])
df.shape
# Out:
# (5000, 19)

# %%
df.head(5)
# Out:
#    account_length  area_code  international_plan  total_intl_minutes  \
# 0             101        510               False                10.6
# 1             137        510               False                 9.5
# 2             103        408               False                13.7
# 3              99        415               False                15.7
# 4             108        415               False                 7.7
#
#    total_intl_calls  voice_mail_plan  number_vmail_messages  \
# 0                 3            False                      0
# 1                 7            False                      0
# 2                 6             True                     29
# 3                 2            False                      0
# 4                 4            False                      0
#
#    total_day_minutes  total_day_calls  total_day_charge  total_eve_minutes  \
# 0               70.9              123             12.05              211.9
# 1              223.6               86             38.01              244.8
# 2              294.7               95             50.10              237.3
# 3              216.8              123             36.86              126.4
# 4              197.4               78             33.56              124.0
#
#    total_eve_calls  total_eve_charge  total_night_minutes  total_night_calls  \
# 0               73             18.01                236.0                 73
# 1              139             20.81                 94.2                 81
# 2              105             20.17                300.3                127
# 3               88             10.74                220.6                 82
# 4              101             10.54                204.5                107
#
#    total_night_charge  total_intl_charge  number_customer_service_calls  churn
# 0               10.62               2.86                              3  False
# 1                4.24               2.57                              0  False
# 2               13.51               3.70                              1  False
# 3                9.93               4.24                              1  False
# 4                9.20               2.08                              2  False

# %% [markdown]
# Another anomaly noted is that where there are records of 'total_intl_minutes', 'total_int_calls', and 'total_intl_charge' when 'international_plan' is False.

# %%
df[(df['international_plan'] == False) & ((df['total_intl_minutes'] > 0) | (df['total_intl_calls'] > 0) |
                                         df['total_intl_charge'] > 0)]
# Out:
#       account_length  area_code  international_plan  total_intl_minutes  \
# 0                101        510               False                10.6
# 1                137        510               False                 9.5
# 2                103        408               False                13.7
# 3                 99        415               False                15.7
# 4                108        415               False                 7.7
# ...              ...        ...                 ...                 ...
# 4994              79        415               False                11.8
# 4995             192        415               False                 9.9
# 4996              68        415               False                 9.6
# 4997              28        510               False                14.1
# 4999              74        415               False                13.7
#
#       total_intl_calls  voice_mail_plan  number_vmail_messages  \
# 0                    3            False                      0
# 1                    7            False                      0
# 2                    6             True                     29
# 3                    2            False                      0
# 4                    4            False                      0
# ...                ...              ...                    ...
# 4994                 5            False                      0
# 4995                 6             True                     36
# 4996                 4            False                      0
# 4997                 6            False                      0
# 4999                 4             True                     25
#
#       total_day_minutes  total_day_calls  total_day_charge  total_eve_minutes  \
# 0                  70.9              123             12.05              211.9
# 1                 223.6               86             38.01              244.8
# 2                 294.7               95             50.10              237.3
# 3                 216.8              123             36.86              126.4
# 4                 197.4               78             33.56              124.0
# ...                 ...              ...               ...                ...
# 4994              134.7               98             22.90              189.7
# 4995              156.2               77             26.55              215.5
# 4996              231.1               57             39.29              153.4
# 4997              180.8              109             30.74              288.8
# 4999              234.4              113             39.85              265.9
#
#       total_eve_calls  total_eve_charge  total_night_minutes  \
# 0                  73             18.01                236.0
# 1                 139             20.81                 94.2
# 2                 105             20.17                300.3
# 3                  88             10.74                220.6
# 4                 101             10.54                204.5
# ...               ...               ...                  ...
# 4994               68             16.12                221.4
# 4995              126             18.32                279.1
# 4996               55             13.04                191.3
# 4997               58             24.55                191.9
# 4999               82             22.60                241.4
#
#       total_night_calls  total_night_charge  total_intl_charge  \
# 0                    73               10.62               2.86
# 1                    81                4.24               2.57
# 2                   127               13.51               3.70
# 3                    82                9.93               4.24
# 4                   107                9.20               2.08
# ...                 ...                 ...                ...
# 4994                128                9.96               3.19
# 4995                 83               12.56               2.67
# 4996                123                8.61               2.59
# 4997                 91                8.64               3.81
# 4999                 77               10.86               3.70
#
#       number_customer_service_calls  churn
# 0                                 3  False
# 1                                 0  False
# 2                                 1  False
# 3                                 1  False
# 4                                 2  False
# ...                             ...    ...
# 4994                              2  False
# 4995                              2  False
# 4996                              3  False
# 4997                              2  False
# 4999                              0  False
#
# [4504 rows x 19 columns]

# %%
df.international_plan.value_counts()
# Out:
# False    4527
# True      473
# Name: international_plan, dtype: int64

# %% [markdown]
# Much as we'd like to remove these invalid variables, doing so would result in a huge loss of data. We will therefore leave them as is, but flag them for future work.

# %% [markdown]
# We will check to confirm that there are no 'number_vmail_messages' when 'voice_mail_plan' is set to False.

# %%
df[(df['voice_mail_plan'] == False) & (df['number_vmail_messages'] > 0)]
# Out:
# Empty DataFrame
# Columns: [account_length, area_code, international_plan, total_intl_minutes, total_intl_calls, voice_mail_plan, number_vmail_messages, total_day_minutes, total_day_calls, total_day_charge, total_eve_minutes, total_eve_calls, total_eve_charge, total_night_minutes, total_night_calls, total_night_charge, total_intl_charge, number_customer_service_calls, churn]
# Index: []

# %% [markdown]
# After confirming this, we can now drop the 'voice_mail_plan' column.

# %%
df.drop(columns = ['voice_mail_plan'],  inplace = True)

# %%
df.dtypes
# Out:
# account_length                     int64
# area_code                          int64
# international_plan                  bool
# total_intl_minutes               float64
# total_intl_calls                   int64
# number_vmail_messages              int64
# total_day_minutes                float64
# total_day_calls                    int64
# total_day_charge                 float64
# total_eve_minutes                float64
# total_eve_calls                    int64
# total_eve_charge                 float64
# total_night_minutes              float64
# total_night_calls                  int64
# total_night_charge               float64
# total_intl_charge                float64
# number_customer_service_calls      int64
# churn                               bool
# dtype: object

# %%
# looking for outliers
num_cols = df.columns.to_list()
num_cols.remove('international_plan')
num_cols.remove('churn')

plt.figure(figsize = (14, 6))
df.boxplot(num_cols)
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# We see that all the remaining variables have outliers, which we will not drop.

# %% [markdown]
# We now save our clean dataset to a new CSV file.

# %%
# save the data set to a clean CSV file

df.to_csv('call_center_clean.csv', index = False)

df = pd.read_csv('call_center_clean.csv')
df.head()
# Out:
#    account_length  area_code  international_plan  total_intl_minutes  \
# 0             101        510               False                10.6
# 1             137        510               False                 9.5
# 2             103        408               False                13.7
# 3              99        415               False                15.7
# 4             108        415               False                 7.7
#
#    total_intl_calls  number_vmail_messages  total_day_minutes  \
# 0                 3                      0               70.9
# 1                 7                      0              223.6
# 2                 6                     29              294.7
# 3                 2                      0              216.8
# 4                 4                      0              197.4
#
#    total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# 0              123             12.05              211.9               73
# 1               86             38.01              244.8              139
# 2               95             50.10              237.3              105
# 3              123             36.86              126.4               88
# 4               78             33.56              124.0              101
#
#    total_eve_charge  total_night_minutes  total_night_calls  \
# 0             18.01                236.0                 73
# 1             20.81                 94.2                 81
# 2             20.17                300.3                127
# 3             10.74                220.6                 82
# 4             10.54                204.5                107
#
#    total_night_charge  total_intl_charge  number_customer_service_calls  churn
# 0               10.62               2.86                              3  False
# 1                4.24               2.57                              0  False
# 2               13.51               3.70                              1  False
# 3                9.93               4.24                              1  False
# 4                9.20               2.08                              2  False

# %% [markdown]
# ## <font color='#2F4F4F'>3. Data Analysis</font>

# %% [markdown]
# ### 3.1 Univariate Analysis

# %%
# get the summary statistics
df.describe()
# Out:
#        account_length    area_code  total_intl_minutes  total_intl_calls  \
# count      5000.00000  5000.000000         5000.000000       5000.000000
# mean        100.25860   436.911400           10.261780          4.435200
# std          39.69456    42.209182            2.761396          2.456788
# min           1.00000   408.000000            0.000000          0.000000
# 25%          73.00000   408.000000            8.500000          3.000000
# 50%         100.00000   415.000000           10.300000          4.000000
# 75%         127.00000   415.000000           12.000000          6.000000
# max         243.00000   510.000000           20.000000         20.000000
#
#        number_vmail_messages  total_day_minutes  total_day_calls  \
# count            5000.000000        5000.000000      5000.000000
# mean                7.755200         180.288900       100.029400
# std                13.546393          53.894699        19.831197
# min                 0.000000           0.000000         0.000000
# 25%                 0.000000         143.700000        87.000000
# 50%                 0.000000         180.100000       100.000000
# 75%                17.000000         216.200000       113.000000
# max                52.000000         351.500000       165.000000
#
#        total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# count       5000.000000        5000.000000      5000.000000       5000.000000
# mean          30.649668         200.636560       100.191000         17.054322
# std            9.162069          50.551309        19.826496          4.296843
# min            0.000000           0.000000         0.000000          0.000000
# 25%           24.430000         166.375000        87.000000         14.140000
# 50%           30.620000         201.000000       100.000000         17.090000
# 75%           36.750000         234.100000       114.000000         19.900000
# max           59.760000         363.700000       170.000000         30.910000
#
#        total_night_minutes  total_night_calls  total_night_charge  \
# count          5000.000000        5000.000000         5000.000000
# mean            200.391620          99.919200            9.017732
# std              50.527789          19.958686            2.273763
# min               0.000000           0.000000            0.000000
# 25%             166.900000          87.000000            7.510000
# 50%             200.400000         100.000000            9.020000
# 75%             234.700000         113.000000           10.560000
# max             395.000000         175.000000           17.770000
#
#        total_intl_charge  number_customer_service_calls
# count        5000.000000                    5000.000000
# mean            2.771196                       1.570400
# std             0.745514                       1.306363
# min             0.000000                       0.000000
# 25%             2.300000                       1.000000
# 50%             2.780000                       1.000000
# 75%             3.240000                       2.000000
# max             5.400000                       9.000000

# %%
print(df.area_code.value_counts())

plt.figure(figsize = (6, 6))
df.area_code.value_counts().plot(kind = 'pie', autopct = '%1.1f%%')
plt.title('Pie Chart of Area Code')
plt.show()
# Out:
# 415    2495
# 408    1259
# 510    1246
# Name: area_code, dtype: int64

# %% [markdown]
# Area Code 415 consists of almost half of the area codes in this dataset. Area Code 510 very slightly outnumbers Area Code 408.

# %%
print(df.international_plan.value_counts())

plt.figure(figsize = (6, 6))
df.international_plan.value_counts().plot(kind = 'bar', rot = 0, color = ['skyblue', 'darkorange'])
plt.title('Distribution of International Plan')
plt.xlabel('International Plan')
plt.show()
# Out:
# False    4527
# True      473
# Name: international_plan, dtype: int64

# %% [markdown]
# Very few of the customers are subscribed to an international plan.

# %%
print(df.number_customer_service_calls.value_counts())

plt.figure(figsize = (8, 8))
df.number_customer_service_calls.value_counts().plot(kind = 'bar', rot = 0)
plt.xlabel("Number of Calls to Customer Service")
plt.show()
# Out:
# 1    1786
# 2    1127
# 0    1023
# 3     665
# 4     252
# 5      96
# 6      34
# 7      13
# 9       2
# 8       2
# Name: number_customer_service_calls, dtype: int64

# %% [markdown]
# Most customers made exactly 1 call to customer service followed by those who made 2 calls, and then those who made 0 calls. Those who made more than 5 calls make up the minority.

# %%
print(df.churn.value_counts())

plt.figure(figsize = (6, 6))
df.churn.value_counts().plot(kind ='bar', rot = 0, color = ['darkgreen', 'darkred'])
plt.xlabel("Churn")
plt.show()
# Out:
# False    4293
# True      707
# Name: churn, dtype: int64

# %% [markdown]
# Majority of the customers in this dataset have not churned, thereby making this dataset very biased.

# %%
# plotting the histograms of all our numerical variables with the
# exception of 'area_code' and 'number_customer_service_calls'
num_cols.remove('area_code')
num_cols.remove('number_customer_service_calls')

fig, axes = plt.subplots(nrows = 7, ncols = 2, figsize = (14, 30))
plt.suptitle('Countplots of Tests Measured', fontsize = 20, y = 1.01, color = 'blue')

colors = ['#00FF7F', '#8B0000', '#C71585', '#0000FF', '#DB7093', '#FFFF00', '#FF4500',
          '#7B68EE', '#FF00FF', '#ADFF2F', '#FFD700', '#A52A2A', '#2F4F4F', '#8B008B']
for ax, column, color in zip(axes.flatten(), num_cols, colors):
    sns.distplot(df[column], ax = ax, color = color, hist_kws = dict(alpha = 0.75))
    
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Majority of the numerical variables have normal distributions. Apart from having most of its values in the 0-5 bin, the 'number_vmail_messages' variable appears to be normally distributed. The 'total_intl_calls' variable is skewed to the right and is not continuous.

# %% [markdown]
# ### 3.2 Bivariata Analysis

# %% [markdown]
# We will make 'churn' our target variable and look at how the other variables relate to it.

# %%
# churn by area code
plt.figure(figsize = (8, 6))
churn_area_code = sns.countplot('area_code', hue = 'churn', data = df)
churn_area_code.set(title = "Churn by Area Code", ylabel = 'Area Code')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Area code 415 reports the highest churn rates.

# %%
# churn by international plan
plt.figure(figsize = (8, 6))
churn_area_code = sns.countplot('international_plan', hue = 'churn', data = df)
churn_area_code.set(title = "Churn by International Plan", ylabel = 'International Plan')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Those without international plans churned more than those with international plans.

# %%
# churn by number of customer service calls
plt.figure(figsize = (8, 6))
churn_area_code = sns.countplot('number_customer_service_calls', hue = 'churn', data = df)
churn_area_code.set(title = "Churn by Number of Customer Service Calls",
                    ylabel = 'Number of Customer Service Calls')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# The interesting thing to note here is that those who made 0 or 2 calls to customer service churned at around the same rate. Similarly, those who made more than 3 calls reported high churn rates.

# %% [markdown]
# ### 3.3 Feature Engineering & Test for Multicollinearity

# %% [markdown]
# Before we can carry out the test for multicollinearity (a requirement for logistic regression), we need to convert the values of 'international_plan' and 'churn' to binary.

# %%
df['international_plan'] = df['international_plan'].replace({False : 0, True : 1})
df['churn'] = df['churn'].replace({False : 0, True : 1})
df.head()
# Out:
#    account_length  area_code  international_plan  total_intl_minutes  \
# 0             101        510                   0                10.6
# 1             137        510                   0                 9.5
# 2             103        408                   0                13.7
# 3              99        415                   0                15.7
# 4             108        415                   0                 7.7
#
#    total_intl_calls  number_vmail_messages  total_day_minutes  \
# 0                 3                      0               70.9
# 1                 7                      0              223.6
# 2                 6                     29              294.7
# 3                 2                      0              216.8
# 4                 4                      0              197.4
#
#    total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# 0              123             12.05              211.9               73
# 1               86             38.01              244.8              139
# 2               95             50.10              237.3              105
# 3              123             36.86              126.4               88
# 4               78             33.56              124.0              101
#
#    total_eve_charge  total_night_minutes  total_night_calls  \
# 0             18.01                236.0                 73
# 1             20.81                 94.2                 81
# 2             20.17                300.3                127
# 3             10.74                220.6                 82
# 4             10.54                204.5                107
#
#    total_night_charge  total_intl_charge  number_customer_service_calls  churn
# 0               10.62               2.86                              3      0
# 1                4.24               2.57                              0      0
# 2               13.51               3.70                              1      0
# 3                9.93               4.24                              1      0
# 4                9.20               2.08                              2      0

# %%
# checking the correlations between the numerical variables

df.corr
# Out:
# <bound method DataFrame.corr of       account_length  area_code  international_plan  total_intl_minutes  \
# 0                101        510                   0                10.6
# 1                137        510                   0                 9.5
# 2                103        408                   0                13.7
# 3                 99        415                   0                15.7
# 4                108        415                   0                 7.7
# ...              ...        ...                 ...                 ...
# 4995             192        415                   0                 9.9
# 4996              68        415                   0                 9.6
# 4997              28        510                   0                14.1
# 4998             184        510                   1                 5.0
# 4999              74        415                   0                13.7
#
#       total_intl_calls  number_vmail_messages  total_day_minutes  \
# 0                    3                      0               70.9
# 1                    7                      0              223.6
# 2                    6                     29              294.7
# 3                    2                      0              216.8
# 4                    4                      0              197.4
# ...                ...                    ...                ...
# 4995                 6                     36              156.2
# 4996                 4                      0              231.1
# 4997                 6                      0              180.8
# 4998                10                      0              213.8
# 4999                 4                     25              234.4
#
#       total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# 0                 123             12.05              211.9               73
# 1                  86             38.01              244.8              139
# 2                  95             50.10              237.3              105
# 3                 123             36.86              126.4               88
# 4                  78             33.56              124.0              101
# ...               ...               ...                ...              ...
# 4995               77             26.55              215.5              126
# 4996               57             39.29              153.4               55
# 4997              109             30.74              288.8               58
# 4998              105             36.35              159.6               84
# 4999              113             39.85              265.9               82
#
#       total_eve_charge  total_night_minutes  total_night_calls  \
# 0                18.01                236.0                 73
# 1                20.81                 94.2                 81
# 2                20.17                300.3                127
# 3                10.74                220.6                 82
# 4                10.54                204.5                107
# ...                ...                  ...                ...
# 4995             18.32                279.1                 83
# 4996             13.04                191.3                123
# 4997             24.55                191.9                 91
# 4998             13.57                139.2                137
# 4999             22.60                241.4                 77
#
#       total_night_charge  total_intl_charge  number_customer_service_calls  \
# 0                  10.62               2.86                              3
# 1                   4.24               2.57                              0
# 2                  13.51               3.70                              1
# 3                   9.93               4.24                              1
# 4                   9.20               2.08                              2
# ...                  ...                ...                            ...
# 4995               12.56               2.67                              2
# 4996                8.61               2.59                              3
# 4997                8.64               3.81                              2
# 4998                6.26               1.35                              2
# 4999               10.86               3.70                              0
#
#       churn
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 4995      0
# 4996      0
# 4997      0
# 4998      0
# 4999      0
#
# [5000 rows x 18 columns]>

# %%
# plotting the correlations onto a heatmap
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), annot=True, cmap ='YlGnBu')

# %% [markdown]
# We see some perfect correlations between the following variables:
# - 'total_day_minutes' and 'total_day_charge'
# - 'total_eve_minutes' and 'total_eve_charge'
# - 'total_night_minutes' and 'total_night_charge'
# - 'total_intl_minutes' and 'total_intl_charge'
#
# We will drop the minutes.

# %%
# drop the columns with minutes, e.g., 'total_day_minutes', etc.

#df.head(5)

df.drop(columns = ['total_day_minutes','total_eve_minutes','total_night_minutes','total_intl_minutes' ], inplace = True)

# %%
df.head(5)
# Out:
#    account_length  area_code  international_plan  total_intl_calls  \
# 0             101        510                   0                 3
# 1             137        510                   0                 7
# 2             103        408                   0                 6
# 3              99        415                   0                 2
# 4             108        415                   0                 4
#
#    number_vmail_messages  total_day_calls  total_day_charge  total_eve_calls  \
# 0                      0              123             12.05               73
# 1                      0               86             38.01              139
# 2                     29               95             50.10              105
# 3                      0              123             36.86               88
# 4                      0               78             33.56              101
#
#    total_eve_charge  total_night_calls  total_night_charge  total_intl_charge  \
# 0             18.01                 73               10.62               2.86
# 1             20.81                 81                4.24               2.57
# 2             20.17                127               13.51               3.70
# 3             10.74                 82                9.93               4.24
# 4             10.54                107                9.20               2.08
#
#    number_customer_service_calls  churn
# 0                              3      0
# 1                              0      0
# 2                              1      0
# 3                              1      0
# 4                              2      0

# %%
# checking the correlations between the numerical variables

corrMatrix = df.corr()
corrMatrix
# Out:
#                                account_length  area_code  international_plan  \
# account_length                       1.000000  -0.018054            0.014681
# area_code                           -0.018054   1.000000            0.032107
# international_plan                   0.014681   0.032107            1.000000
# total_intl_calls                     0.014277  -0.013623            0.004493
# number_vmail_messages               -0.014575  -0.003399            0.011947
# total_day_calls                      0.028240  -0.019314            0.008102
# total_day_charge                    -0.001019  -0.019119            0.028141
# total_eve_calls                      0.009143  -0.012300            0.002505
# total_eve_charge                    -0.009587   0.007114            0.021234
# total_night_calls                   -0.007825   0.014657            0.005623
# total_night_charge                   0.000656   0.002070           -0.026510
# total_intl_charge                    0.001292  -0.004219            0.031751
# number_customer_service_calls       -0.001445   0.020921           -0.012974
# churn                                0.021203   0.010195            0.259123
#
#                                total_intl_calls  number_vmail_messages  \
# account_length                         0.014277              -0.014575
# area_code                             -0.013623              -0.003399
# international_plan                     0.004493               0.011947
# total_intl_calls                       1.000000               0.000124
# number_vmail_messages                  0.000124               1.000000
# total_day_calls                        0.010893               0.000883
# total_day_charge                      -0.001307               0.005377
# total_eve_calls                        0.005574              -0.003954
# total_eve_charge                       0.008393               0.019496
# total_night_calls                     -0.000156               0.002676
# total_night_charge                    -0.017182               0.005535
# total_intl_charge                      0.016900               0.002505
# number_customer_service_calls         -0.019147              -0.007086
# churn                                 -0.046893              -0.097633
#
#                                total_day_calls  total_day_charge  \
# account_length                        0.028240         -0.001019
# area_code                            -0.019314         -0.019119
# international_plan                    0.008102          0.028141
# total_intl_calls                      0.010893         -0.001307
# number_vmail_messages                 0.000883          0.005377
# total_day_calls                       1.000000          0.001936
# total_day_charge                      0.001936          1.000000
# total_eve_calls                       0.003754          0.008129
# total_eve_charge                     -0.000695         -0.010757
# total_night_calls                    -0.008308          0.004235
# total_night_charge                    0.002802          0.011785
# total_intl_charge                     0.013161         -0.019419
# number_customer_service_calls        -0.010739          0.002726
# churn                                 0.016130          0.207700
#
#                                total_eve_calls  total_eve_charge  \
# account_length                        0.009143         -0.009587
# area_code                            -0.012300          0.007114
# international_plan                    0.002505          0.021234
# total_intl_calls                      0.005574          0.008393
# number_vmail_messages                -0.003954          0.019496
# total_day_calls                       0.003754         -0.000695
# total_day_charge                      0.008129         -0.010757
# total_eve_calls                       1.000000          0.002778
# total_eve_charge                      0.002778          1.000000
# total_night_calls                    -0.013682          0.013422
# total_night_charge                    0.001799         -0.016652
# total_intl_charge                    -0.007507          0.000155
# number_customer_service_calls         0.006235         -0.013836
# churn                                -0.006284          0.089282
#
#                                total_night_calls  total_night_charge  \
# account_length                         -0.007825            0.000656
# area_code                               0.014657            0.002070
# international_plan                      0.005623           -0.026510
# total_intl_calls                       -0.000156           -0.017182
# number_vmail_messages                   0.002676            0.005535
# total_day_calls                        -0.008308            0.002802
# total_day_charge                        0.004235            0.011785
# total_eve_calls                        -0.013682            0.001799
# total_eve_charge                        0.013422           -0.016652
# total_night_calls                       1.000000            0.026949
# total_night_charge                      0.026949            1.000000
# total_intl_charge                       0.000368           -0.006650
# number_customer_service_calls          -0.008283           -0.008530
# churn                                  -0.006986            0.045673
#
#                                total_intl_charge  \
# account_length                          0.001292
# area_code                              -0.004219
# international_plan                      0.031751
# total_intl_calls                        0.016900
# number_vmail_messages                   0.002505
# total_day_calls                         0.013161
# total_day_charge                       -0.019419
# total_eve_calls                        -0.007507
# total_eve_charge                        0.000155
# total_night_calls                       0.000368
# total_night_charge                     -0.006650
# total_intl_charge                       1.000000
# number_customer_service_calls          -0.012180
# churn                                   0.063275
#
#                                number_customer_service_calls     churn
# account_length                                     -0.001445  0.021203
# area_code                                           0.020921  0.010195
# international_plan                                 -0.012974  0.259123
# total_intl_calls                                   -0.019147 -0.046893
# number_vmail_messages                              -0.007086 -0.097633
# total_day_calls                                    -0.010739  0.016130
# total_day_charge                                    0.002726  0.207700
# total_eve_calls                                     0.006235 -0.006284
# total_eve_charge                                   -0.013836  0.089282
# total_night_calls                                  -0.008283 -0.006986
# total_night_charge                                 -0.008530  0.045673
# total_intl_charge                                  -0.012180  0.063275
# number_customer_service_calls                       1.000000  0.212564
# churn                                               0.212564  1.000000

# %%
# plotting the correlations onto a heatmap

plt.figure(figsize=(12,12))
sns.heatmap(corrMatrix, annot = True, cmap ='rocket')

# %% [markdown]
# We will then check the Variance Inflation Factor (VIF) scores to ensure there is no high multicollinearity.

# %%
# calculate VIF and plot the heatmap

# load statmodels functions
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from statsmodels.tools.tools import add_constant

# %%
X= df.iloc[:,0:13] # independent variables

y= df['churn'] #dependent variable

# %%
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor

#find design matrix for linear regression model using 'rating' as response variable 
y, X = dmatrices('churn ~ +area_code+international_plan+total_intl_calls+number_vmail_messages+total_day_calls+total_day_charge+total_eve_calls+total_eve_charge+total_night_calls+total_night_charge+total_intl_charge+number_customer_service_calls', data=df, return_type='dataframe')

#calculate VIF for each explanatory variable
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['variable'] = X.columns

#view VIF for each explanatory variable 
vif
# Out:
#            VIF                       variable
# 0   248.259706                      Intercept
# 1     1.002891                      area_code
# 2     1.004506             international_plan
# 3     1.001329               total_intl_calls
# 4     1.000662          number_vmail_messages
# 5     1.000913                total_day_calls
# 6     1.002010               total_day_charge
# 7     1.000576                total_eve_calls
# 8     1.001697               total_eve_charge
# 9     1.001502              total_night_calls
# 10    1.002324             total_night_charge
# 11    1.002111              total_intl_charge
# 12    1.001642  number_customer_service_calls

# %%
plt.figure(figsize=(12,12))
sns.heatmap( vif, annot = True, cmap ='rocket')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-528-8ea957df56ea> in <module>()
#       1 plt.figure(figsize=(12,12))
# ----> 2 sns.heatmap( vif, annot = True, cmap ='rocket')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 542                           yticklabels, mask)
#     543
#     544     # Add the pcolormesh kwargs here
#
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     158         # Determine good default values for the colormapping
#     159         self._determine_cmap_params(plot_data, vmin, vmax,
# --> 160                                     cmap, center, robust)
#     161
#     162         # Sort out the annotations
#
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     191
#     192         # plot_data is a np.ma.array instance
# --> 193         calc_data = plot_data.astype(float).filled(np.nan)
#     194         if vmin is None:
#     195             if robust:
#
# ValueError: could not convert string to float: 'Intercept'

# %% [markdown]
# We don't see any VIF score of 5 and above, which means our dataset does not have high levels of multicollinearity. We are, therefore, good to go.

# %% [markdown]
# ## <font color='#2F4F4F'>4. Data Modeling</font>

# %% [markdown]
# We will carry out 5 types of classification analysis, namely:
# 1. Logistic Regression
# 2. Gaussian Naive Bayes (NB) classification
# 3. Decision Trees Classification
# 4. K-Nearest Neighbors (KNN) Classification
# 5. Support Vector Machine (SVM) Classification
#
# We will then compare the different classification models to assess the best performing one(s).

# %%
# dividing our dataset into features (X) and target (y)

features= df.iloc[:,0:13].values.astype('float')

target = df['churn'].values.astype('float')

# %%
target
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
features
# Out:
# array([[101.  , 510.  ,   0.  , ...,  10.62,   2.86,   3.  ],
#        [137.  , 510.  ,   0.  , ...,   4.24,   2.57,   0.  ],
#        [103.  , 408.  ,   0.  , ...,  13.51,   3.7 ,   1.  ],
#        ...,
#        [ 28.  , 510.  ,   0.  , ...,   8.64,   3.81,   2.  ],
#        [184.  , 510.  ,   1.  , ...,   6.26,   1.35,   2.  ],
#        [ 74.  , 415.  ,   0.  , ...,  10.86,   3.7 ,   0.  ]])

# %%
# splitting into 80-20 train-test sets

# load libraries
from sklearn.model_selection import train_test_split

features_train, features_valid, target_train, target_valid = train_test_split(
    features, target, test_size=0.20, random_state=12345
)

# %%
print('Features Train Shape: ', features_train.shape, '\nFeatures Validation Shape: ',features_valid.shape, 
      '\nTarget Train Shape: ',target_train.shape, '\nTarget Validation Shape: ',target_valid.shape)
# Out:
# Features Train Shape:  (4000, 13)
# Features Validation Shape:  (1000, 13)
# Target Train Shape:  (4000,)
# Target Validation Shape:  (1000,)

# %%
# performing feature scaling on our training data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# fitting and transforming X_train while transforming X_test

sc_X = StandardScaler()
sc_y = StandardScaler()

features_train = sc_X.fit_transform(features_train)
features_valid = sc_y.fit_transform(features_valid)

# %%
# loading our classification libraries
from sklearn.linear_model import LogisticRegression # Logistic Regression Classifier
from sklearn.naive_bayes import GaussianNB          # Naive Bayes Classifier
from sklearn.tree import DecisionTreeClassifier     # Decision Tree Classifier
from sklearn.neighbors import KNeighborsRegressor   # KNN Classifier
from sklearn.svm import SVR                         # SVM Classifier

# %%
# instantiating our classifiers
logreg = LogisticRegression(random_state=12345,class_weight='balanced',solver='liblinear')
decsntree =DecisionTreeClassifier( random_state=12345,class_weight='balanced')
nayes= GaussianNB()
knn= KNeighborsRegressor()
svrmodel= SVR()

# %%
# fitting our classifiers to the training data
# Below, we make an instance classifier of the object LogisticRegression, 
# DecisionTreeClassifier, SVC, GaussianNB, KNeighborsClassifier, GaussianNB.

logreg.fit(features_train, target_train)
decsntree.fit(features_train, target_train)
nayes.fit(features_train, target_train)
svrmodel.fit(features_train, target_train)
knn.fit(features_train, target_train)
# Out:
# KNeighborsRegressor()

# %%
logreg_pred = logreg.predict(features_valid)        #logistic regression predict
decsntree_pred = decsntree.predict(features_valid)  #decision tree predict
nayes_pred = nayes.predict(features_valid)          #nayes predict
knn_pred = knn.predict(features_valid)              #KNeighborsRegressor predict
svrmodel_pred = svrmodel.predict(features_valid)    #Support Vector Machine predict

# %%
#Printing evaluation metrics to determine the accuracy of classifiers

from sklearn.metrics import classification_report, accuracy_score 

print(accuracy_score(logreg_pred, target_valid))
print(accuracy_score(decsntree_pred, target_valid))
print(accuracy_score(nayes_pred, target_valid))
#print(accuracy_score(knn_pred, target_valid))
#print(accuracy_score(svr_model_pred, target_valid))
# Out:
# 0.755
# 0.913
# 0.855

# %%
# classification report for Logistic Regression
print("Logistic Regression classification report:")
print(classification_report(target_valid, logreg_pred))

# classification report for Gaussian Naive Bayes Classifier
print("Gaussian Naive Bayes classification report:")
print(classification_report(target_valid, nayes_pred))

# classification report for Decision Tree Classifier
print("Decision Tree classification report:")
print(classification_report(target_valid, decsntree_pred))

'''
# classification report for K-Nearest Neighbors Classifier
print("K-Nearest Neighbors classification report:")
print(classification_report(target_valid, knn_pred))


# classification report for Support Vector Machine Classifier
print("Support Vector Machine classification report:")

print(classification_report(target_valid, svrmodel_pred))

'''
# Out:
# Logistic Regression classification report:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.76      0.84       874
#          1.0       0.30      0.73      0.43       126
#
#     accuracy                           0.76      1000
#    macro avg       0.63      0.74      0.64      1000
# weighted avg       0.87      0.76      0.79      1000
#
# Gaussian Naive Bayes classification report:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.93      0.92       874
#          1.0       0.41      0.35      0.38       126
#
#     accuracy                           0.85      1000
#    macro avg       0.66      0.64      0.65      1000
# weighted avg       0.85      0.85      0.85      1000
#
# Decision Tree classification report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.94      0.95       874
#          1.0       0.63      0.74      0.68       126
#
#     accuracy                           0.91      1000
#    macro avg       0.80      0.84      0.82      1000
# weighted avg       0.92      0.91      0.92      1000
# '\n# classification report for K-Nearest Neighbors Classifier\nprint("K-Nearest Neighbors classification report:")\nprint(classification_report(target_valid, knn_pred))\n\n\n# classification report for Support Vector Machine Classifier\nprint("Support Vector Machine classification report:")\n\nprint(classification_report(target_valid, svrmodel_pred))\n\n'

# %% [markdown]
# What have you noticed about the performance of the various models?
#
# The most accurate score is decision tree at 91%
# Our support tells us that our dataset is highly imbalanced i.e. 874 0's and 126 1's.
# From the weighted avg which takes into account of our imbalanced
# dataset we get 87%, 85% &80%, with decsion tree, being the most accurate classifiers.
# We can then further perform model opmization techiniques i.e.
# data cleaning, feature engineering, checking for model assumptions, etc.
# to further get the best classifier.

# %% [markdown]
# ## <font color='#2F4F4F'>5. Summary of Findings</font>
#
# Include your findings from the analysis and modeling stages.
#
# From the analysis,area code 415 has the highest churn, though it's population  as compared to other areas is high.
# Those without international plans churned more than those with international plans.
# customers who called more than three have the highest churn.
# after removing the minutes, the other variables are not correlated. with <0.5 correlation, also dataset does not have high levels of multicollinearity after doing vif score.
# Decision tree gives the most acurate results at 91%.

# %% [markdown]
# ## <font color='#2F4F4F'>6. Recommendations</font>
#
# What recommendations can you provide?
#
# Do further cleaning to balance the data more.

# %% [markdown]
# ## <font color='#2F4F4F'>7. Challenging your Solution</font>
#
# What can you do to improve your project?
# Do more data cleaning, feature engineering, checking for model assumptions to get better model results
